# %%
import spacy

nlp = spacy.blank("en")

doc = nlp("Captain america ate 100$ of samosa. Then he said I can do this all day.")

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x792e85440b30>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x792e85440e30>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x792e85553d80>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x792e853ca2d0>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x792e853cb0d0>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x792e85553ed0>)]
