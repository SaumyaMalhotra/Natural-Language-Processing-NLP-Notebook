# %%
import nltk
import spacy

# %% [markdown]
# # **Stemming**

# %%
from nltk.stem import PorterStemmer

stemmer= PorterStemmer()

# %%
words = ["eating", "eats", "eat", "ate", "adjustable", "rafting", "ability", "meeting"]

for word in words:
  print(word, "--->" ,stemmer.stem(word))
# Out:
# eating ---> eat
# eats ---> eat
# eat ---> eat
# ate ---> ate
# adjustable ---> adjust
# rafting ---> raft
# ability ---> abil
# meeting ---> meet

# %%
nlp=spacy.load("en_core_web_sm")

# %%
ar=nlp.get_pipe("attribute_ruler")
ar.add([
    [{"TEXT":"Bro"}],
    [{"TEXT":"Brah"}]],
     {"LEMMA":"Brother"})

# %% [markdown]
# # **Lemmatization** with Custom Attritubte Ruler

# %%
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")

for tokens in doc:
  print(tokens.text , "|" , tokens.lemma_)
# Out:
# Bro | Brother
# , | ,
# you | you
# wanna | wanna
# go | go
# ? | ?
# Brah | Brother
# , | ,
# do | do
# n't | not
# say | say
# no | no
# ! | !
# I | I
# am | be
# exhausted | exhaust
